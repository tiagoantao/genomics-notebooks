# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %% [markdown]
# ## (dominant) Selection vs Drift

# %%
m = SelectionPop(gens=100)
m.freq = 0.05
m.sel = [0.05, 0.05, 0.2]
m.neutral_loci = 9
#m.sel_type = ['recessive', 'hz_advantage', 'dominant']
m.sel_type = 'dominant'
m.pop_size = [50, 200, 10000]
BasicViewTwo(m, FreqDerived(), highlight=[0])
m.run()

# %% [markdown]
# ## Recessive

# %%
m = SelectionPop(gens=100)
m.freq = 0.05
m.sel = [0.05, 0.2]
m.neutral_loci = 9
m.sel_type = 'recessive'
m.pop_size = [50, 200, 10000]
BasicViewTwo(m, FreqDerived(), highlight=[0])
m.run()

# %% [markdown]
# ## Hz advantage

# %%
m = SelectionPop(gens=100)
m.freq = 0.05
m.sel = [0.05, 0.2]
m.neutral_loci = 9
m.sel_type = 'hz_advantage'
m.pop_size = [50, 200, 10000]
BasicViewTwo(m, FreqDerived(), highlight=[0])
m.run()
