# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = SelectionPop(gens=100)
m.freq = [0.01, 0.5]
m.sel = 0.2
m.sel_type = ['recessive', 'hz_advantage', 'dominant']
m.pop_size = 200
BasicViewTwo(m, FreqDerived())

# %%
m.run()
