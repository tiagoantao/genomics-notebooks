# %%
import sys

sys.path.append('../src')

from popgen import *

# %matplotlib inline

# %%
m = Bottleneck(gens=100)
m.bgen = 50
m.start_size = 1000
m.end_size = [50, 100, 250, 750]
m.num_msats = 20
BasicView(m, [ExpHe(), NumAlleles()], with_model=True)
m.run()

# %%
m = Bottleneck(gens=100)
m.bgen = 50
m.start_size = 1000
m.end_size = 100
m.num_msats = 20
BasicView(m, [ExpHe(), LDNe()], with_model=True)
m.run()

# %%
m = Bottleneck(gens=100)
m.bgen = 50
m.start_size = 100
m.end_size = 1000
m.num_msats = 20
BasicView(m, [ExpHe(), LDNe()])
m.run()

# %%
m = Bottleneck(gens=20)
m.bgen = 10
m.num_stats = 100
m.start_size = 200
m.end_size = 50
m.sample_size = [10, 50, 100]
BasicView(m, [LDNe()])
m.run()

# %%
m = Bottleneck(gens=20)
m.bgen = 10
m.start_size = 500
m.end_size = [400, 50]
m.sample_size = 50
m.num_stats = 50
BasicView(m, [ExpHe(), LDNe()])
m.run()

# %%
m = Bottleneck(gens=20)
m.bgen = 10
m.start_size = 100
m.end_size = 50
m.num_msats = [10, 20, 50]
BasicView(m, [ExpHe(), LDNe()])
m.run()
