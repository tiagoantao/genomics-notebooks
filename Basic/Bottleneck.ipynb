# %%
import sys

sys.path.append('../src')

from popgen import *

# %matplotlib inline

# %%
m = Bottleneck(gens=20)
m.bgen = 10
m.start_size = 500
m.end_size = 100
m.num_msats = [10, 20, 50]
#BasicView(m, [ExpHe(), NumAlleles(), LDNe()])
BasicView(m, [ExpHe()])
m.run()

# %%
m = Bottleneck(gens=100)
m.bgen = 50
m.start_size = 500
m.end_size = 50
m.num_msats = 10
BasicView(m, [ExpHe(), NumAlleles()])
m.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-24edcd446139> in <module>()
#       4 m.end_size = 50
#       5 m.num_msats = 10
# ----> 6 BasicView(m, [ExpHe(), NumAlleles()])
#       7 m.run()
#
# /home/tra/Dropbox/soft/genomics-notebooks/src/model.py in __init__(self)
#     387         self.name = 'NumAlleles'
#     388         self.desc = 'Number of Alleles'
# --> 389         self.simupop_stats = [sp.Stat(alleleFreq=True)]
#     390
#     391     def get_values(self, pop):
#
# AttributeError: can't set attribute
