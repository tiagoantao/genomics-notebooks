# %%
import sys

sys.path.append('../src')

from popgen import *

# %matplotlib inline

# %%
m = Bottleneck(gens=20)
m.bgen = 10
m.start_size = 500
m.end_size = 100
m.num_msats = [10, 20, 50]
BasicView(m, [ExpHe(), NumAlleles(), LDNe()])
m.run()
