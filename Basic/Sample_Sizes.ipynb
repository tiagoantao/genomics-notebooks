# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = SinglePop(gens=20)
m.num_msats = 50
m.pop_size = 50
m.sample_size = [5, 10, 50]
BasicView(m, [ExpHe(), NumAlleles(), LDNe()], max_y=[None, None, m.pop_size * 3])
m.run()

# %%
m = SinglePop(gens=20)
m.num_msats = 50
m.pop_size = [50, 100]
m.sample_size = [5, 10, 50]
BasicViewTwo(m, LDNe(), max_y=m.pop_size[-1] * 3)
m.run()

# %%
m = SinglePop(gens=20)
m.num_msats = [10, 20, 50]
m.pop_size = 50
BasicView(m, [ExpHe(), LDNe()], max_y=[None, m.pop_size * 3])
m.run()
