# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = SinglePop(gens=100)
m.num_msats = 10
m.pop_size = 500
m.mut_msat = [0.01, 0.001, 0.0001, 0.00001, 0.000001, 0]
BasicView(m, [ExpHe(), NumAlleles()], ['mean'])
m.run()
