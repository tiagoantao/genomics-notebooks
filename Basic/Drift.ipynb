# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = SinglePop(gens=100)
m.num_msats = 10
m.pop_size = 50
#m.sample_size = [5, 10, 100]
m.pop_size = 50
BasicView(m, [ExpHe(), NumAlleles()], ['mean'])
m.run()

# %%
m = SinglePop(gens=100)
m.num_msats = 3
m.pop_size = 50
#m.sample_size = [5, 10, 100]
m.pop_size = [50, 100, 200, 500]
BasicView(m, [ExpHe(), NumAlleles()], ['mean'])
m.run()

# %%
m = SinglePop(gens=100)
m.num_msats = 3
m.pop_size = 50
#m.sample_size = [5, 10, 100]
m.pop_size = [50, 50, 50, 50]
BasicView(m, [ExpHe(), NumAlleles()], ['mean'])
m.run()

# %%
m = SinglePop(gens=100)
m.num_msats = 3
m.pop_size = 50
m.sample_size = [5, 10, 100]
m.pop_size = 100
BasicView(m, [ExpHe(), NumAlleles()], ['mean'])
m.run()

# %%
m.png
