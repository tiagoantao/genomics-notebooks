# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = SinglePop(gens=100)
m.num_msats = 3
m.pop_size = 1000
m.sample_size = [5, 10, 100]
#m.pop_size = [500, 500, 500, 500]
#BasicView(m, [ExpHe(), NumAlleles()])
BasicView(m, [ExpHe()])

m.run()

# %%
m.png
