# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = SinglePop(gens=100)
m.num_msats = 5
m.pop_size = [50, 100, 200, 1000]
BasicView(m, [ExpHe(), NumAlleles()])

# %%
m.run()
