# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = Island(gens=100)
m.mig = [0, 0.01]
m.pop_size = [50, 500]
m.num_pops = 5
m.num_msats = 10
BasicViewTwo(m, FST())
BasicViewTwo(m, NumAlleles())
#BasicViewTwo(m, ExpHe())
MetaVsDemeView(m, ExpHe(), ExpHe(do_structured=True))
MetaVsDemeView(m, NumAlleles(), NumAlleles(do_structured=True))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-13acc983c528> in <module>()
#       4 m.num_pops = 5
#       5 m.num_msats = 10
# ----> 6 BasicViewTwo(m, FST())
#       7 BasicViewTwo(m, NumAlleles())
#       8 #BasicViewTwo(m, ExpHe())
#
# /home/tra/Dropbox/soft/genomics-notebooks/src/model.py in __init__(self)
#     444         self.name = 'FST'
#     445         self.desc = 'FST'
# --> 446         self.simupop_stats = [sp.Stat(structure=sp.ALL_AVAIL)]
#     447
#     448     def _get_values(self, pop):
#
# AttributeError: can't set attribute

# %%
m.run()
