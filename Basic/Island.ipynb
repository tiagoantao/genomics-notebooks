# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = Island(gens=100)
m.mig = 0.001
m.pop_size = [50, 100, 500]
m.num_pops = [2, 5, 10]
m.num_msats = 10
BasicViewTwo(m, FST())
BasicViewTwo(m, NumAlleles())
BasicViewTwo(m, ExpHe())

# %%
m.run()
