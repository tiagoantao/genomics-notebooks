# %%
import sys
sys.path.append('../src')
from popgen import *
# %matplotlib inline

# %%
m = Island(gens=100)
m.mig = [0.001, 0.01, 0.1]
m.pop_size = [50, 100, 500]
m.num_pops = 5
m.num_msats = 10
BasicViewTwo(m, FST())
BasicViewTwo(m, NumAlleles())
BasicViewTwo(m, ExpHe())

# %%
m.run()
